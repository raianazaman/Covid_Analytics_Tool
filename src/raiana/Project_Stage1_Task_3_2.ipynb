# %% [markdown]
# <a href="https://colab.research.google.com/github/UNCG-CSE/COVID-Team-2/blob/master/src/raiana/Project_Stage1_Task_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Raiana Zaman
#
# Hospital Beds Dataset:
# https://coronavirus-resources.esri.com/datasets/1044bb19da8d4dbfb6a96eb1b4ebf629_0/data?geometry=-40.957%2C-16.820%2C15.996%2C72.123
#
# Task: Read the Enrichment data and displays them on a notebook.

# %% [markdown]
# #Load Data

# %%
import pandas as pd
import numpy as np

#READING THE FILE
HospitalBed_dataset = pd.read_csv("/content/drive/My Drive/Datascience/Project/COVID-Team-2/data/Definitive_Health_USA_Hospital_Beds.csv")

#Show Data
HospitalBed_dataset.head(20)
# Out:
#              X  ...  AVG_VENTILATOR_USAGE
# 0  -112.066157  ...                     0
# 1  -110.965885  ...                     2
# 2  -119.779742  ...                     2
# 3   -72.957610  ...                     2
# 4   -75.606533  ...                     1
# 5   -77.011195  ...                     2
# 6   -82.345254  ...                     2
# 7  -116.190185  ...                     1
# 8   -93.721683  ...                     2
# 9   -90.105308  ...                     2
# 10  -92.328849  ...                     2
# 11 -106.581643  ...                     1
# 12  -73.774440  ...                     2
# 13  -73.906405  ...                     2
# 14  -96.774530  ...                     1
# 15 -123.365057  ...                     0
# 16  -79.960807  ...                     2
# 17  -86.451938  ...                     2
# 18  -87.888307  ...                     3
# 19  -87.785172  ...                     2
#
# [20 rows x 23 columns]

# %%
#show data shape for enrichment data
HospitalBed_dataset.shape
# Out:
# (6621, 23)

# %%
#Show dataframe stats
HospitalBed_dataset.dtypes
# Out:
# X                                  float64
# Y                                  float64
# OBJECTID                             int64
# HOSPITAL_NAME                       object
# HOSPITAL_TYPE                       object
# HQ_ADDRESS                          object
# HQ_ADDRESS1                         object
# HQ_CITY                             object
# HQ_STATE                            object
# HQ_ZIP_CODE                          int64
# COUNTY_NAME                         object
# STATE_NAME                          object
# STATE_FIPS                         float64
# CNTY_FIPS                          float64
# FIPS                               float64
# NUM_LICENSED_BEDS                  float64
# NUM_STAFFED_BEDS                   float64
# NUM_ICU_BEDS                         int64
# ADULT_ICU_BEDS                       int64
# PEDI_ICU_BEDS                      float64
# BED_UTILIZATION                    float64
# Potential_Increase_In_Bed_Capac      int64
# ...
